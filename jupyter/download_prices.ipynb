# %% [markdown]
# # Download Prices
#
# Reuses the forward-PE data already in `forward_pe.csv` and only refreshes the 1-month/2-week price performance fields, then rewrites `forward_pe.csv`, `screen.csv`, and `sorted_screen.csv`. Does not hit Yahoo Finance for forward-PE/debt/liquidity fields, so it's much faster than the full download. Equivalent to `python main.py prices`.

# %%
import os
import sys

if os.path.basename(os.getcwd()) == "jupyter":
    os.chdir("..")
sys.path.insert(0, os.getcwd())

from main import download_prices

# %%
download_prices()
# Out:
# Loaded 2314 tickers from forward_pe.csv
# Wrote forward_pe.csv
# Wrote screen.csv
# Wrote sorted_screen.csv
